# %% [markdown]
# <a href="https://colab.research.google.com/github/nsaali/ASU-Graduate-Courses/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import math 
from matplotlib import pyplot as plt
from numpy import linalg as la
from scipy import integrate 
import sympy as sp 
# Number 1 
x , y = sp . symbols ('x y')
# a
eqx = x - y
eqy = 3*x - 4*y
equil = sp . nonlinsolve ([eqx , eqy], [x , y])
print ( equil )
equil = list ( equil )
system = sp . Matrix ([eqx , eqy ])
variables = sp . Matrix ([x , y])
J= system . jacobian ( variables )
print (J)
for i in range ( len ( equil ) ):
  Jequil = J.subs([(x , equil [i][0]) , (y , equil [i][1])])
print (" Jequil =", Jequil ) 

Jequil.tolist ()
Jequil = np.array(Jequil , dtype = float)
print (" Jequil =", Jequil )
eigvals , eigvecs = la.eig ( Jequil )
print (" Eigenvalues of (", equil [i][0],",", equil [i][1],"): ",eigvals )
Realpart = eigvals.real
if all ( Realpart <0):
  print ("=> equilibrium is stable \n")
elif min ( Realpart )* max ( Realpart )<0: 
  print ("=> equilibrium is a saddle \n")
else :
  print ("=> equilibrium is unstable \n")

# b

eqx = 2*x - 2*y
eqy = 5*x - 2*y
equil = sp . nonlinsolve ([eqx , eqy], [x , y])
print ( equil )
equil = list ( equil )
system = sp . Matrix ([eqx , eqy ])
variables = sp . Matrix ([x , y])
J= system . jacobian ( variables )
print (J)
for i in range ( len ( equil ) ):
  Jequil = J.subs([(x , equil [i][0]) , (y , equil [i][1])])
print (" Jequil =", Jequil ) 

Jequil.tolist ()
Jequil = np.array(Jequil , dtype = float)
print (" Jequil =", Jequil )
eigvals , eigvecs = la.eig ( Jequil )
print (" Eigenvalues of (", equil [i][0],",", equil [i][1],"): ",eigvals )
Realpart = eigvals.real
if all ( Realpart <0):
  print ("=> equilibrium is stable \n")
elif min ( Realpart )* max ( Realpart )<0: 
  print ("=> equilibrium is a saddle \n")
else :
  print ("=> equilibrium is unstable \n")

# c

eqx = 3*x - 5*y
eqy = -17*x - 5*y
equil = sp . nonlinsolve ([eqx , eqy], [x , y])
print ( equil )
equil = list ( equil )
system = sp . Matrix ([eqx , eqy ])
variables = sp . Matrix ([x , y])
J= system . jacobian ( variables )
print (J)
for i in range ( len ( equil ) ):
  Jequil = J.subs([(x , equil [i][0]) , (y , equil [i][1])])
print (" Jequil =", Jequil ) 

Jequil.tolist ()
Jequil = np.array(Jequil , dtype = float)
print (" Jequil =", Jequil )
eigvals , eigvecs = la.eig ( Jequil )
print (" Eigenvalues of (", equil [i][0],",", equil [i][1],"): ",eigvals )
Realpart = eigvals.real
if all ( Realpart <0):
  print ("=> equilibrium is stable \n")
elif min ( Realpart )* max ( Realpart )<0: 
  print ("=> equilibrium is a saddle \n")
else :
  print ("=> equilibrium is unstable \n")

# d

eqx = -3*x - 5*y
eqy = x - 6*y
equil = sp . nonlinsolve ([eqx , eqy], [x , y])
print ( equil )
equil = list ( equil )
system = sp . Matrix ([eqx , eqy ])
variables = sp . Matrix ([x , y])
J= system . jacobian ( variables )
print (J)
for i in range ( len ( equil ) ):
  Jequil = J.subs([(x , equil [i][0]) , (y , equil [i][1])])
print (" Jequil =", Jequil ) 

Jequil.tolist ()
Jequil = np.array(Jequil , dtype = float)
print (" Jequil =", Jequil )
eigvals , eigvecs = la.eig ( Jequil )
print (" Eigenvalues of (", equil [i][0],",", equil [i][1],"): ",eigvals )
Realpart = eigvals.real
if all ( Realpart <0):
  print ("=> equilibrium is stable \n")
elif min ( Realpart )* max ( Realpart )<0: 
  print ("=> equilibrium is a saddle \n")
else :
  print ("=> equilibrium is unstable \n")

# Number 2

#2-d Vector field
tgrid =np . linspace (-3 , 3 , 12 )
xgrid =np . linspace (-3 , 3 , 12 )
X1 , Y1 = np . meshgrid ( tgrid , xgrid )
U = Y1
V = -Y1 - X1
N = np . sqrt (U ** 2 + V ** 2)
U = U / N
V = V / N
plt . quiver (X1 , Y1 , U , V , angles ="xy", 
              scale_units ='xy', scale =3 , headlength =2 ,
headwidth = 2 , color ='red')
plt . xlim ([-3 , 3])
plt . ylim ([-3 , 3])
plt . xlabel ('x')
plt . ylabel ('y')
plt . show () # Normally , we would not just plot the vector field .
# Now define the system of ODEs . This is for x’=y, y’= -x-y:
def Ex2dSystem (x , t=0 ):
  return ([x[1], -x[0] -x[1]])

x_init =[[3 ,1], [-1 ,0], [1 ,3], [3 ,-5], [-.15 , 0], [-3 , 2]]
# the above initial conditions are by trial and error
t = np . linspace (0 , 15 , 1000 )
# Plot trajectories by looping through the possible values
for i in range ( len ( x_init )):
# Starting point of each trajectory
  x0 = x_init[i]
# Integrate system of ODEs to get x and y values
x = integrate . odeint ( Ex2dSystem , x0 , t)
# Plot each trajectory
plt . plot ( x[:,0], x[:,1])
# Now re - plot direction field .
plt . title ('phase plane : trajectories and direction fields')
plt . xlabel ('x')
plt . ylabel ('y')
plt . quiver (X1 , Y1 , U , V , angles ="xy", scale_units = 'xy', scale =3 , headlength =2
  , headwidth =2 , color = 'red')
plt . xlim ([-3 , 3])


# Number 3 

# a 
tgrid =np . linspace (-3 , 3 , 12 )
xgrid =np . linspace (-3 , 3 , 12 )
X1 , Y1 = np . meshgrid ( tgrid , xgrid )
U = Y1
V = -Y1 - X1
N = np . sqrt (U ** 2 + V ** 2)
U = U / N
V = V / N
plt . quiver (X1 , Y1 , U , V , angles ="xy", 
              scale_units ='xy', scale =3 , headlength =2 ,
headwidth = 2 , color ='red')
plt . xlim ([-2 , 2])
plt . ylim ([-2 , 2])
plt . xlabel ('x')
plt . ylabel ('y')
plt . show () 

def Ex2dSystem (x , t=0 ):
  return ([-5*x[0] + 8*x[1],-4*x[0] + 7*x[1]])

x_init =[[3 ,1], [-1 ,0], [1 ,3], [3 ,-5], [-.15 , 0], [-3 , 2]]
t = np . linspace (0 , 15 , 1000 )
for i in range ( len ( x_init )):
  x0 = x_init[i]
x = integrate . odeint ( Ex2dSystem , x0 , t)
plt . plot ( x[:,0], x[:,1])
plt . title ('phase plane : trajectories and direction fields')
plt . xlabel ('x')
plt . ylabel ('y')
plt . quiver (X1 , Y1 , U , V , angles ="xy", scale_units = 'xy', scale =3 , headlength =2
  , headwidth =2 , color = 'red')
plt . xlim ([-3 , 3])

# b

tgrid =np . linspace (-3 , 3 , 12 )
xgrid =np . linspace (-3 , 3 , 12 )
X1 , Y1 = np . meshgrid ( tgrid , xgrid )
U = Y1
V = -Y1 - X1
N = np . sqrt (U ** 2 + V ** 2)
U = U / N
V = V / N
plt . quiver (X1 , Y1 , U , V , angles ="xy", 
              scale_units ='xy', scale =3 , headlength =2 ,
headwidth = 2 , color ='red')
plt . xlim ([-2 , 2])
plt . ylim ([-2 , 2])
plt . xlabel ('x')
plt . ylabel ('y')
plt . show () 

def Ex2dSystem (x , t=0 ):
  return ([2*x[0] - 2*x[1],5*x[0] + 2*x[1]])

x_init =[[3 ,1], [-1 ,0], [1 ,3], [3 ,-5], [-.15 , 0], [-3 , 2]]
t = np . linspace (0 , 15 , 1000 )
for i in range ( len ( x_init )):
  x0 = x_init[i]
x = integrate . odeint ( Ex2dSystem , x0 , t)
plt . plot ( x[:,0], x[:,1])
plt . title ('phase plane : trajectories and direction fields')
plt . xlabel ('x')
plt . ylabel ('y')
plt . quiver (X1 , Y1 , U , V , angles ="xy", scale_units = 'xy', scale =3 , headlength =2
  , headwidth =2 , color = 'red')
plt . xlim ([-3 , 3])

# c 

tgrid =np . linspace (-3 , 3 , 12 )
xgrid =np . linspace (-3 , 3 , 12 )
X1 , Y1 = np . meshgrid ( tgrid , xgrid )
U = Y1
V = -Y1 - X1
N = np . sqrt (U ** 2 + V ** 2)
U = U / N
V = V / N
plt . quiver (X1 , Y1 , U , V , angles ="xy", 
              scale_units ='xy', scale =3 , headlength =2 ,
headwidth = 2 , color ='red')
plt . xlim ([-2 , 2])
plt . ylim ([-2 , 2])
plt . xlabel ('x')
plt . ylabel ('y')
plt . show () 

def Ex2dSystem (x , t=0 ):
  return ([3*x[0] - 5*x[1],-17*x[0] - 5*x[1]])

x_init =[[3 ,1], [-1 ,0], [1 ,3], [3 ,-5], [-.15 , 0], [-3 , 2]]
t = np . linspace (0 , 15 , 1000 )
for i in range ( len ( x_init )):
  x0 = x_init[i]
x = integrate . odeint ( Ex2dSystem , x0 , t)
plt . plot ( x[:,0], x[:,1])
plt . title ('phase plane : trajectories and direction fields')
plt . xlabel ('x')
plt . ylabel ('y')
plt . quiver (X1 , Y1 , U , V , angles ="xy", scale_units = 'xy', scale =3 , headlength =2
  , headwidth =2 , color = 'red')
plt . xlim ([-3 , 3])

# d

tgrid =np . linspace (-3 , 3 , 12 )
xgrid =np . linspace (-3 , 3 , 12 )
X1 , Y1 = np . meshgrid ( tgrid , xgrid )
U = Y1
V = -Y1 - X1
N = np . sqrt (U ** 2 + V ** 2)
U = U / N
V = V / N
plt . quiver (X1 , Y1 , U , V , angles ="xy", 
              scale_units ='xy', scale =3 , headlength =2 ,
headwidth = 2 , color ='red')
plt . xlim ([-2 , 2])
plt . ylim ([-2 , 2])
plt . xlabel ('x')
plt . ylabel ('y')
plt . show () 

def Ex2dSystem (x , t=0 ):
  return ([-3*x[0] - 5*x[1], x[0] - 6*x[1]])

x_init =[[3 ,1], [-1 ,0], [1 ,3], [3 ,-5], [-.15 , 0], [-3 , 2]]
t = np . linspace (0 , 15 , 1000 )
for i in range ( len ( x_init )):
  x0 = x_init[i]
x = integrate . odeint ( Ex2dSystem , x0 , t)
plt . plot ( x[:,0], x[:,1])
plt . title ('phase plane : trajectories and direction fields')
plt . xlabel ('x')
plt . ylabel ('y')
plt . quiver (X1 , Y1 , U , V , angles ="xy", scale_units = 'xy', scale =3 , headlength =2
  , headwidth =2 , color = 'red')
plt . xlim ([-3 , 3])

# Number 4

tgrid =np . linspace (-.3 , 4 , 12 )
xgrid =np . linspace (-.3 , 4 , 12 )
X1 , Y1 = np . meshgrid ( tgrid , xgrid )
U = X1 * (3 - X1 - 2*Y1 )
V = Y1 * (2- X1 - Y1 )
N = np . sqrt (U ** 2 + V ** 2)
U = U / N
V = V / N
plt . quiver (X1 , Y1 , U , V , angles ="xy", scale_units ='xy', scale =7 , headlength =2 ,
headwidth =2 , color = 'red')
plt . xlabel ('x')
plt . ylabel ('y')
def Ex2dSystem ( xvec , t=0):
  x = xvec [0] #we redefine with the problem ’s variables to match
  y = xvec [1]
  return ([x * (3 - x - 2*y) ,y * ( 2 - y - x)])

x_init =[[4 ,2], [.1 ,0], [1 ,4], [4 ,0], [0 ,.1], [0 ,4], [.2 ,.1], [.1 ,.2], [.1 ,.3],
[4 , 3], [4 ,4],[2 , 4]]
# the above initial conditions are by trial and error
t = np . linspace (0 , 15 , 1000 )
for i in range ( len ( x_init )):
  x0 = x_init [i]
  x = integrate . odeint ( Ex2dSystem , x0 , t)
plt . plot ( x[:,0], x[:,1])
plt . title ('rabbits (x) vs. sheep (y)')
plt . xlim ([-2 , 3])
plt . ylim ([-.5 , 4])
plt . show ()

# Number 5

x , y = sp . symbols ('x y')
eqx = x * (3 - x - 2*y)
eqy = y * (2 - y - x)
equil = sp . nonlinsolve ([eqx , eqy], [x , y])
print ( equil )
equil = list ( equil )
system = sp . Matrix ([eqx , eqy ])
variables = sp . Matrix ([x , y])
J= system . jacobian ( variables )
print (J)
for i in range ( len ( equil ) ):
  Jequil = J. subs ([(x , equil [i][0]) , (y , equil [i][1])])
print (" Jequil =", Jequil ) #we can ’t do computations on this

Jequil . tolist ()
Jequil = np . array ( Jequil , dtype = float ) # now we can use np and la commands
print (" Jequil =", Jequil )
eigvals , eigvecs = la . eig ( Jequil )
print (" Eigenvalues of (", equil [i][0],",", equil [i][1],"): ",eigvals )
Realpart = eigvals . real
if all ( Realpart <0):
  print ("=> equilibrium is stable \n")
elif min ( Realpart )* max ( Realpart )<0: # then 2 eigs have opposite signs
  print ("=> equilibrium is a saddle \n")
else :
  print ("=> equilibrium is unstable \n")

# Number 6

# a

# EQUILIBRIA AND STABILITY 
eqx = x * (3 - x) - x*y
eqy = y * (2 - y) - x*y
equil = sp . nonlinsolve ([eqx , eqy], [x , y])
print ( equil )
equil = list ( equil )
system = sp . Matrix ([eqx , eqy ])
variables = sp . Matrix ([x , y])
J= system . jacobian ( variables )
print (J)
for i in range ( len ( equil ) ):
  Jequil = J. subs ([(x , equil [i][0]) , (y , equil [i][1])])
print (" Jequil =", Jequil ) 

Jequil . tolist ()
Jequil = np . array ( Jequil , dtype = float ) 
print (" Jequil =", Jequil )
eigvals , eigvecs = la . eig ( Jequil )
print (" Eigenvalues of (", equil [i][0],",", equil [i][1],"): ",eigvals )
Realpart = eigvals . real
if all ( Realpart <0):
  print ("=> equilibrium is stable \n")
elif min ( Realpart )* max ( Realpart )<0: 
  print ("=> equilibrium is a saddle \n")
else :
  print ("=> equilibrium is unstable \n")

#    PLOT 

tgrid =np . linspace (-3 , 3 , 12 )
xgrid =np . linspace (-3 , 3 , 12 )
X1 , Y1 = np . meshgrid ( tgrid , xgrid )
U = Y1
V = -Y1 - X1
N = np . sqrt (U ** 2 + V ** 2)
U = U / N
V = V / N
plt . quiver (X1 , Y1 , U , V , angles ="xy", 
              scale_units ='xy', scale =3 , headlength =2 ,
headwidth = 2 , color ='red')
plt . xlim ([-2 , 2])
plt . ylim ([-2 , 2])
plt . xlabel ('x')
plt . ylabel ('y')
plt . show () 

def Ex2dSystem (x , t=0 ):
  return ([x[0]*(3-x[0]) - x[0]*x[1], x[1]*(2-x[1]) - x[0]*x[1]])

x_init =[[3 ,1], [-1 ,0], [1 ,3], [3 ,-5], [-.15 , 0], [-3 , 2]]
t = np . linspace (0 , 15 , 1000 )
for i in range ( len ( x_init )):
  x0 = x_init[i]
x = integrate . odeint ( Ex2dSystem , x0 , t)
plt . plot ( x[:,0], x[:,1])
plt . title ('phase plane : trajectories and direction fields')
plt . xlabel ('x')
plt . ylabel ('y')
plt . quiver (X1 , Y1 , U , V , angles ="xy", scale_units = 'xy', scale =3 , headlength =2
  , headwidth =2 , color = 'red')
plt . xlim ([-3 , 3])

# b

# EQUILIBRIA AND STABILITY 
eqx = x * (3 - 2*x) - x*y
eqy = y * (2 - y) - x*y
equil = sp.nonlinsolve([eqx , eqy], [x , y])
print ( equil )
equil = list ( equil )
system = sp . Matrix ([eqx , eqy ])
variables = sp . Matrix ([x , y])
J= system . jacobian ( variables )
print (J)
for i in range ( len ( equil ) ):
  Jequil = J. subs ([(x , equil [i][0]) , (y , equil [i][1])])
print (" Jequil =", Jequil ) 

Jequil . tolist ()
Jequil = np . array ( Jequil , dtype = float ) 
print (" Jequil =", Jequil )
eigvals , eigvecs = la . eig ( Jequil )
print (" Eigenvalues of (", equil [i][0],",", equil [i][1],"): ",eigvals )
Realpart = eigvals . real
if all ( Realpart <0):
  print ("=> equilibrium is stable \n")
elif min ( Realpart )* max ( Realpart )<0: 
  print ("=> equilibrium is a saddle \n")
else :
  print ("=> equilibrium is unstable \n")

#    PLOT 

tgrid =np . linspace (-3 , 3 , 12 )
xgrid =np . linspace (-3 , 3 , 12 )
X1 , Y1 = np . meshgrid ( tgrid , xgrid )
U = Y1
V = -Y1 - X1
N = np . sqrt (U ** 2 + V ** 2)
U = U / N
V = V / N
plt . quiver (X1 , Y1 , U , V , angles ="xy", 
              scale_units ='xy', scale =3 , headlength =2 ,
headwidth = 2 , color ='red')
plt . xlim ([-2 , 2])
plt . ylim ([-2 , 2])
plt . xlabel ('x')
plt . ylabel ('y')
plt . show () 

def Ex2dSystem (x , t=0 ):
  return ([x[0]*(3-2*x[0]) - x[0]*x[1], x[1]*(2-x[1]) - x[0]*x[1]])

x_init =[[3 ,1], [-1 ,0], [1 ,3], [3 ,-5], [-.15 , 0], [-3 , 2]]
t = np . linspace (0 , 15 , 1000 )
for i in range ( len ( x_init )):
  x0 = x_init[i]
x = integrate . odeint ( Ex2dSystem , x0 , t)
plt . plot ( x[:,0], x[:,1])
plt . title ('phase plane : trajectories and direction fields')
plt . xlabel ('x')
plt . ylabel ('y')
plt . quiver (X1 , Y1 , U , V , angles ="xy", scale_units = 'xy', scale =3 , headlength =2
  , headwidth =2 , color = 'red')
plt . xlim ([-3 , 3])

# c

# EQUILIBRIA AND STABILITY 
eqx = x * (3 - 2*x) - 2*x*y
eqy = y * (2 - y) - x*y
equil = sp . nonlinsolve ([eqx , eqy], [x , y])
print ( equil )
equil = list ( equil )
system = sp . Matrix ([eqx , eqy ])
variables = sp . Matrix ([x , y])
J= system . jacobian ( variables )
print (J)
for i in range ( len ( equil ) ):
  Jequil = J. subs ([(x , equil [i][0]) , (y , equil [i][1])])
print (" Jequil =", Jequil ) 

Jequil . tolist ()
Jequil = np . array ( Jequil , dtype = float ) 
print (" Jequil =", Jequil )
eigvals , eigvecs = la . eig ( Jequil )
print (" Eigenvalues of (", equil [i][0],",", equil [i][1],"): ",eigvals )
Realpart = eigvals . real
if all ( Realpart <0):
  print ("=> equilibrium is stable \n")
elif min ( Realpart )* max ( Realpart )<0: 
  print ("=> equilibrium is a saddle \n")
else :
  print ("=> equilibrium is unstable \n")

#    PLOT 

tgrid =np . linspace (-3 , 3 , 12 )
xgrid =np . linspace (-3 , 3 , 12 )
X1 , Y1 = np . meshgrid ( tgrid , xgrid )
U = Y1
V = -Y1 - X1
N = np . sqrt (U ** 2 + V ** 2)
U = U / N
V = V / N
plt . quiver (X1 , Y1 , U , V , angles ="xy", 
              scale_units ='xy', scale =3 , headlength =2 ,
headwidth = 2 , color ='red')
plt . xlim ([-2 , 2])
plt . ylim ([-2 , 2])
plt . xlabel ('x')
plt . ylabel ('y')
plt . show () 

def Ex2dSystem (x , t=0 ):
  return ([x[0]*(3-2*x[0]) - 2*x[0]*x[1], x[1]*(2-x[1]) - x[0]*x[1]])

x_init =[[3 ,1], [-1 ,0], [1 ,3], [3 ,-5], [-.15 , 0], [-3 , 2]]
t = np . linspace (0 , 15 , 1000 )
for i in range ( len ( x_init )):
  x0 = x_init[i]
x = integrate . odeint ( Ex2dSystem , x0 , t)
plt . plot ( x[:,0], x[:,1])
plt . title ('phase plane : trajectories and direction fields')
plt . xlabel ('x')
plt . ylabel ('y')
plt . quiver (X1 , Y1 , U , V , angles ="xy", scale_units = 'xy', scale =3 , headlength =2
  , headwidth =2 , color = 'red')
plt . xlim ([-3 , 3])

# Number 7
a = sp.symbols('a')
# a

# b

eqx = x**2*(1-x) - x*y
eqy = y*(x - a)
equil = sp . nonlinsolve ([eqx , eqy], [x , y])
print ( equil )
equil = list ( equil )
system = sp . Matrix ([eqx , eqy ])
variables = sp . Matrix ([x , y])
J= system . jacobian ( variables )
print (J)
for i in range ( len ( equil ) ):
  Jequil = J.subs([(x , equil [i][0]) , (y , equil [i][1])])
print (" Jequil =", Jequil ) 

Jequil.tolist ()
Jequil = np.array(Jequil , dtype = float)
print (" Jequil =", Jequil )
eigvals , eigvecs = la.eig ( Jequil )
print (" Eigenvalues of (", equil [i][0],",", equil [i][1],"): ",eigvals )
Realpart = eigvals.real
if all ( Realpart <0):
  print ("=> equilibrium is stable \n")
elif min ( Realpart )* max ( Realpart )<0: 
  print ("=> equilibrium is a saddle \n")
else :
  print ("=> equilibrium is unstable \n")

# c

tgrid =np . linspace (-3 , 3 , 12 )
xgrid =np . linspace (-3 , 3 , 12 )
X1 , Y1 = np . meshgrid ( tgrid , xgrid )
U = Y1
V = -Y1 - X1
N = np . sqrt (U ** 2 + V ** 2)
U = U / N
V = V / N
plt . quiver (X1 , Y1 , U , V , angles ="xy", 
              scale_units ='xy', scale =3 , headlength =2 ,
headwidth = 2 , color ='red')
plt . xlim ([-2 , 2])
plt . ylim ([-2 , 2])
plt . xlabel ('x')
plt . ylabel ('y')
plt . show () 

def Ex2dSystem (x , t=0 ):
  return ([x[0]**2*(1-x[0]) - x[0]*x[1], x[1]*(x[0]-a)])

x_init =[[3 ,1], [-1 ,0], [1 ,3], [3 ,-5], [-.15 , 0], [-3 , 2]]
t = np . linspace (0 , 15 , 1000 )
for i in range ( len ( x_init )):
  x0 = x_init[i]
x = integrate . odeint ( Ex2dSystem , x0 , t)
plt . plot ( x[:,0], x[:,1])
plt . title ('phase plane : trajectories and direction fields')
plt . xlabel ('x')
plt . ylabel ('y')
plt . quiver (X1 , Y1 , U , V , angles ="xy", scale_units = 'xy', scale =3 , headlength =2
  , headwidth =2 , color = 'red')
plt . xlim ([-3 , 3])

# d

# e

#  Number 8

#  Number 9

#  Number 10

# See https :// matplotlib . org / stable / gallery / subplots axes and figures / subplots demo . html
N = 10000
mu = 1/( 70* 365 ) #1/ days
nu = . 01 # vaccination rate
beta = . 87 # transmission rate
alpha = 1/21 #1/ days
def Ex_SIR_System ( xvec , t=0):
S = xvec [0]
I = xvec [1]
R = xvec [2]
return ([ mu*N - ( mu+nu )*S - beta *(I/N)*S ,
beta *(I/N)*S - alpha *I - mu*I ,
alpha *I - mu*R + nu*S])
fig , axs = plt . subplots (3 )
t = np . linspace (0 , 50 , 1000 )
x0=[9995 ,5 , 0]
x = integrate . odeint ( Ex_SIR_System , x0 , t)
fig . suptitle (’SIR with vital dynamics and vaccination ’)
Splot = axs [0]. plot (t , x[:,0], ’r-’)
Iplot = axs [1]. plot (t , x[:,1], ’b -. ’)
Rplot = axs [2]. plot (t , x[:,2], ’k--’)
axs [0].set ( xlabel =" time ( days )", ylabel ="S")
axs [1].set ( xlabel =" time ( days )", ylabel ="I")
axs [2].set ( xlabel =" time ( days )", ylabel ="R")
axs [0]. legend (" Susceptible ")
axs [1]. legend (" Infected ")
axs [2]. legend (" Recovered ")
plt . show ()
import sympy as sp
import scipy . linalg as la
S , I , R = sp . symbols (’S I R’)
eqS = mu*N - ( mu+nu )*S - beta *(I/N )*S
eqI = beta *( I/N)*S - alpha *I - mu*I
eqR = alpha *I - mu*R + nu*S
equil = sp . nonlinsolve ([eqS , eqI , eqR ], [S , I , R])
print (" The equilibria , (S,I,R), are ", equil )
equil = list ( equil )
system = sp . Matrix ([eqS , eqI , eqR ]) #we must keep the order the same
variables = sp . Matrix ([S , I , R])
J= system . jacobian ( variables )
for i in range ( len ( equil ) ):
Jequil = J. subs ([(S , equil [i][0]) , (I , equil [i][1]) , (R , equil [i][2])])
Jequil . tolist ()
Jequil = np . array ( Jequil , dtype = float ) # now can use np and la commands
eigvals , eigvecs = la . eig ( Jequil ) # calculatues eigenvas & eigenvecs of A
print (" The eigenvalues of (", equil [i][0],",", equil [i][1],",", equil [i][2],
"):",eigvals )
if min ( equil [i]) < -1e-9:
# depending on the answers , -1e -9 might be needed for this check of
# begin negative since numerically this number could be considered 0.
print ("=> Negative component (s) make this equilibrium not biologically relevant
.\n")
else : # all components are nonnegative
print ("=> All components are nonnegative ; the equilibrium isbiologically
relevant .")
if all ( eigvals . real <0):
print (" All Re( eigenvalues )<0 = > equilibrium is stable \n")
else :
print (" Some of Re( eigenvalues )>0=> equilibrium is unstable \n")
# Out:
# FiniteSet((0, 0))
# Matrix([[1, -1], [3, -4]])
#  Jequil = Matrix([[1, -1], [3, -4]])
#  Jequil = [[ 1. -1.]
#  [ 3. -4.]]
#  Eigenvalues of ( 0 , 0 ):  [ 0.30277564 -3.30277564]
# => equilibrium is a saddle
#
# FiniteSet((0, 0))
# Matrix([[2, -2], [5, -2]])
#  Jequil = Matrix([[2, -2], [5, -2]])
#  Jequil = [[ 2. -2.]
#  [ 5. -2.]]
#  Eigenvalues of ( 0 , 0 ):  [8.32667268e-17+2.44948974j 8.32667268e-17-2.44948974j]
# => equilibrium is unstable
#
# FiniteSet((0, 0))
# Matrix([[3, -5], [-17, -5]])
#  Jequil = Matrix([[3, -5], [-17, -5]])
#  Jequil = [[  3.  -5.]
#  [-17.  -5.]]
#  Eigenvalues of ( 0 , 0 ):  [  9.04987562 -11.04987562]
# => equilibrium is a saddle
#
# FiniteSet((0, 0))
# Matrix([[-3, -5], [1, -6]])
#  Jequil = Matrix([[-3, -5], [1, -6]])
#  Jequil = [[-3. -5.]
#  [ 1. -6.]]
#  Eigenvalues of ( 0 , 0 ):  [-4.5+1.6583124j -4.5-1.6583124j]
# => equilibrium is stable
# FiniteSet((0, 0), (0, 2), (1, 1), (3, 0))
# Matrix([[-2*x - 2*y + 3, -2*x], [-y, -x - 2*y + 2]])
# ...
