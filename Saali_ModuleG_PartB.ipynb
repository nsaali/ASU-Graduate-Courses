# %% [markdown]
# <a href="https://colab.research.google.com/github/nsaali/ASU-Graduate-Courses/blob/main/Saali_ModuleG_PartB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nick Saali Module G Part B 
# Computing Integrals using R
# CRAN, R-Bloggers, GitHub, RPubs, Stackoverflow 

#install.packages('deSolve')
#install.packages('ggplot2')
#install.packages('reshape2')
library(deSolve)
library(reshape2)
library(ggplot2)

        # Sequence with interval
    time <- seq(0, 10, by = 0.5)
    
    # Initial Condition
    x0 <- 0.1
   
   
    ## Fxn that we'll integrate
    f <- function(x){x * (1.-x)}
    
    ## Empty vector for storing results and insert initial condition
    x <- c()
    x[1] <- x0
    
    # for loop
    for (i in 1:(length(time)-1)){
        x[i+1] = x[i] + 0.5 * f(x[i])
    }
    
    plot(x~time, col='red')
    curve(0.1 * exp(x)/(1+0.1*(exp(x)-1.)), add=T, col='blue')
    legend("topleft", c("Numerical", "Analytical"), 
           pch=c(1,NA), lty=c(NA,1), col=c('red','blue'))
# Out:
# plot without title
