# %% [markdown]
# <a href="https://colab.research.google.com/github/nsaali/ASU-Graduate-Courses/blob/main/Saali_HW6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Number 1
import numpy as np
import matplotlib . pyplot as plt
import scipy . linalg as la
L = np . array ([[0 ,4 , 20 , 55],[.05 ,0 ,0 ,0],[0 ,.25 ,0 , 0],[0 ,0 ,.5 ,0]])
print (L)
x = np . array ([[500],[50],[6],[3]])
L1=np . dot (L ,x)
print ( L1 )
L2=np . dot ( np . linalg . matrix_power (L ,2) ,x )
print ( L2 )
L3=np . dot ( np . linalg . matrix_power (L ,3) ,x )
print ( L3 )
L4=np . dot ( np . linalg . matrix_power (L ,4) ,x )
print ( L4 )
L5=np . dot ( np . linalg . matrix_power (L ,5) ,x )
print ( L5 )
L6=np . dot ( np . linalg . matrix_power (L ,6) ,x )
print ( L6 )
L7=np . dot ( np . linalg . matrix_power (L ,7) ,x )
print ( L7 )
L8=np . dot ( np . linalg . matrix_power (L ,8) ,x )
print ( L8 )
print ([np .sum( L1 ) ,np . sum ( L2 ) , np . sum ( L3 ) ,np .sum( L4 ) ,np . sum ( L5 ) , np . sum ( L6 ) ,
np .sum ( L7 ) ,np . sum ( L8 )]) # observe the total population over the years
eigvals , eigvecs = la . eig (L)
print ( eigvals )
print ( eigvecs )
print (" magnitude of eigenvalues : \n", np . absolute ( eigvals ))

# Number 2

Lf = np . array ([[.434 ,0 ,.56],[.33 ,.61 ,0],[0 ,.304 ,.956 ]])
print ( Lf )
eigvals , eigvecs = la . eig ( Lf )
print (" magnitude of eigenvalues : \n", np . absolute ( eigvals ))
print ("V ( eigenvectors as columns )=", eigvecs )
v= eigvecs [:,-1]
print (" Last column of V:", v) # corresponds to dominant eigenvalue
W=la . inv ( eigvecs )
print ("W= inv (V)=", W)
vright =v/np . sum (v )
wt=W[-1]. real # use . real if the entries are complex - valued
print (" Last Row of Re(W) =", wt )
wleft =wt/wt[0]
print ( np . outer ( vright , wleft )) # needed for outer product
print ( np . dot ( wleft , vright ) ) # inner product , same command as matrix mult
sens =( np . outer ( vright , wleft ) )/np .dot( wleft , vright )
print (" sensitivity matrix is: ", sens )

# Number 3
f2 = 10
f3 = 50
P1 = 0.05
P2 = 0.25
Ls = np . array ([[0, f2, f3],[P1, 0, 0],[0, P2, 0]])
print(Ls)
eigvals , eigvecs = la . eig ( Ls )
print (" magnitude of eigenvalues : \n", np . absolute ( eigvals ))
print ("V ( eigenvectors as columns )=", eigvecs )
v= eigvecs [:,-1]
print (" Last column of V:", v) 
W=la . inv ( eigvecs )
print ("W= inv (V)=", W)
vright =v/np . sum (v )
wt=W[-1].real 
print (" Last Row of Re(W) =", wt )
wleft =wt/wt[0]
print ( np . outer ( vright , wleft )) 
print ( np . dot ( wleft , vright ) ) 
sens =( np . outer ( vright , wleft ) )/np .dot( wleft , vright )
print (" sensitivity matrix is: ", sens )

# Number 4

Ls = np . array ([[0, 0, 1000],[0.02, 0, 0],[0, 0.05, 0]])
print(Ls)
eigvals , eigvecs = la . eig ( Ls)
print (" magnitude of eigenvalues : \n", np . absolute ( eigvals ))
print ("V ( eigenvectors as columns )=", eigvecs )
v= eigvecs [:,-1]
print (" Last column of V:", v) 
W=la . inv ( eigvecs )
print ("W= inv (V)=", W)
vright =v/np . sum (v )
wt=W[-1].real 
print (" Last Row of Re(W) =", wt )
wleft =wt/wt[0]
print ( np . outer ( vright , wleft )) 
print ( np . dot ( wleft , vright ) ) 
sens =( np . outer ( vright , wleft ) )/np .dot( wleft , vright )
print (" sensitivity matrix is: ", sens )

### Interpretation: 
###   The 




# Number 5

Lf = np . array ([[0, 0, 0, 4.665, 61.896],[0.675, 0.703, 0, 0, 0],
                  [0, 0.047, 0.657, 0, 0], [0, 0, 0.019, 0.682, 0], 
                  [0, 0, 0, 0.061, 0.8091]])
print(Lf)
eigvals , eigvecs = la . eig ( Lf )
print (" magnitude of eigenvalues : \n", np . absolute ( eigvals ))
print ("V ( eigenvectors as columns )=", eigvecs )
v= eigvecs [:,-1]
print (" Last column of V:", v) 
W=la . inv ( eigvecs )
print ("W= inv (V)=", W)
vright =v/np . sum (v )
wt=W[-1].real 
print (" Last Row of Re(W) =", wt )
wleft =wt/wt[0]
print ( np . outer ( vright , wleft )) 
print ( np . dot ( wleft , vright ) ) 
sens =( np . outer ( vright , wleft ) )/np .dot( wleft , vright )
print (" sensitivity matrix is: ", sens )

### Interpretation:
###
# Out:
# [[0.0e+00 4.0e+00 2.0e+01 5.5e+01]
#  [5.0e-02 0.0e+00 0.0e+00 0.0e+00]
#  [0.0e+00 2.5e-01 0.0e+00 0.0e+00]
#  [0.0e+00 0.0e+00 5.0e-01 0.0e+00]]
# [[485. ]
#  [ 25. ]
#  [ 12.5]
#  [  3. ]]
# [[515.  ]
#  [ 24.25]
#  [  6.25]
#  [  6.25]]
# [[565.75  ]
#  [ 25.75  ]
#  [  6.0625]
#  [  3.125 ]]
# [[396.125  ]
#  [ 28.2875 ]
#  [  6.4375 ]
#  [  3.03125]]
# [[408.61875 ]
#  [ 19.80625 ]
#  [  7.071875]
#  [  3.21875 ]]
# [[397.69375  ]
#  [ 20.4309375]
#  [  4.9515625]
#  [  3.5359375]]
# [[375.2315625 ]
#  [ 19.8846875 ]
#  [  5.10773437]
#  [  2.47578125]]
# [[317.86140625]
#  [ 18.76157813]
#  [  4.97117188]
#  [  2.55386719]]
# [525.5, 551.75, 600.6875, 433.88125, 438.715625, 426.61218750000006, 402.699765625, 344.14802343749994]
# [ 0.93045348+0.j         -0.71909902+0.j         -0.10567723+0.70893668j
#  -0.10567723-0.70893668j]
# [[ 0.99842555+0.j          0.9971614 +0.j         -0.99713926+0.j
#   -0.99713926-0.j        ]
#  [ 0.05365263+0.j         -0.06933408+0.j          0.01025529+0.0687977j
#    0.01025529-0.0687977j ]
#  [ 0.01441572+0.j          0.0241045 +0.j          0.02320615-0.00707564j
#    0.02320615+0.00707564j]
#  [ 0.00774661+0.j         -0.01676021+0.j         -0.00726853-0.01528339j
#   -0.00726853+0.01528339j]]
#  magnitude of eigenvalues :
#  [0.93045348 0.71909902 0.71676976 0.71676976]
# [[0.434 0.    0.56 ]
#  [0.33  0.61  0.   ]
#  [0.    0.304 0.956]]
#  magnitude of eigenvalues :
#  [0.52600327 0.52600327 1.11779407]
# V ( eigenvectors as columns )= [[ 0.66721373+0.j          0.66721373-0.j          0.58587624+0.j        ]
#  [-0.33613444-0.57027287j -0.33613444+0.57027287j  0.38074324+0.j        ]
#  [ 0.00846285+0.34140405j  0.00846285-0.34140405j  0.71539053+0.j        ]]
#  Last column of V: [0.58587624+0.j 0.38074324+0.j 0.71539053+0.j]
# W= inv (V)= [[ 0.63537409+2.87819634e-01j -0.2362425 +5.57900534e-01j
#   -0.39461362-5.32637105e-01j]
#  [ 0.63537409-2.87819634e-01j -0.2362425 -5.57900534e-01j
#   -0.39461362+5.32637105e-01j]
#  [ 0.25967834-1.84685096e-17j  0.53808033+0.00000000e+00j
#    0.89879605+2.24219070e-17j]]
#  Last Row of Re(W) = [0.25967834 0.53808033 0.89879605]
# [[0.34831912+0.j 0.72175317+0.j 1.20559861+0.j]
#  [0.22636205+0.j 0.46904554+0.j 0.78348206+0.j]
#  [0.42531883+0.j 0.88130453+0.j 1.47210925+0.j]]
# (2.289473909219038+0j)
#  sensitivity matrix is:  [[0.15213937+0.j 0.31524848+0.j 0.52658325+0.j]
#  [0.09887077+0.j 0.20487045+0.j 0.34221052+0.j]
#  [0.18577143+0.j 0.38493757+0.j 0.64299018+0.j]]
# [[ 0.   10.   50.  ]
#  [ 0.05  0.    0.  ]
#  [ 0.    0.25  0.  ]]
#  magnitude of eigenvalues :
#  [1.04727574 0.77251956 0.77251956]
# V ( eigenvectors as columns )= [[ 0.99879753+0.j          0.99769409+0.j          0.99769409-0.j        ]
#  [ 0.04768551+0.j         -0.0437703 -0.04747596j -0.0437703 +0.04747596j]
#  [ 0.01138323+0.j         -0.00169455+0.0208284j  -0.00169455-0.0208284j ]]
#  Last column of V: [ 0.99769409-0.j         -0.0437703 +0.04747596j -0.00169455-0.0208284j ]
# W= inv (V)= [[ 0.39353601-3.03675250e-17j  8.2428143 +0.00000000e+00j
#   18.78855746+2.66453526e-15j]
#  [ 0.30416999+8.27919578e-02j -4.1259654 +2.58812817e+00j
#   -9.40466873-1.81063433e+01j]
#  [ 0.30416999-8.27919578e-02j -4.1259654 -2.58812817e+00j
#   -9.40466873+1.81063433e+01j]]
#  Last Row of Re(W) = [ 0.30416999 -4.1259654  -9.40466873]
# [[ 1.04692582e+00-0.02929759j -1.42012027e+01+0.39741216j
#   -3.23700260e+01+0.9058558j ]
#  [-4.45360169e-02+0.05110402j  6.04116351e-01-0.6932091j
#    1.37701450e+00-1.58009129j]
#  [-2.38979975e-03-0.02180642j  3.24168438e-02+0.29579695j
#    7.38905076e-02+0.67423549j]]
# (1.7249326751528382-0.04827120839697008j)
#  sensitivity matrix is:  [[ 6.06937205e-01+6.63226801e-17j -8.23290260e+00-9.00380627e-16j
#   -1.87659649e+01-1.99369996e-15j]
#  [-2.66272208e-02+2.88815266e-02j  3.61189449e-01-3.91768364e-01j
#    8.23290260e-01-8.92991415e-01j]
#  [-1.03086196e-03-1.26707471e-02j  1.39833018e-02+1.71874497e-01j
#    3.18733456e-02+3.91768364e-01j]]
# [[0.e+00 0.e+00 1.e+03]
#  [2.e-02 0.e+00 0.e+00]
#  [0.e+00 5.e-02 0.e+00]]
#  magnitude of eigenvalues :
#  [1. 1. 1.]
# V ( eigenvectors as columns )= [[ 9.99799560e-01+0.j          9.99799560e-01-0.j
#   -9.99799560e-01+0.j        ]
#  [-9.99799560e-03-0.01731704j -9.99799560e-03+0.01731704j
#   -1.99959912e-02+0.j        ]
#  [-4.99899780e-04+0.00086585j -4.99899780e-04-0.00086585j
#   -9.99799560e-04+0.j        ]]
#  Last column of V: [-9.99799560e-01+0.j -1.99959912e-02+0.j -9.99799560e-04+0.j]
# W= inv (V)= [[ 3.3340016e-01-2.77555756e-17j -8.3350040e+00+1.44366504e+01j
#   -1.6670008e+02-2.88733008e+02j]
#  [ 3.3340016e-01-5.55111512e-17j -8.3350040e+00-1.44366504e+01j
#   -1.6670008e+02+2.88733008e+02j]
#  [-3.3340016e-01-5.55111512e-17j -1.6670008e+01+0.00000000e+00j
#   -3.3340016e+02-0.00000000e+00j]]
#  Last Row of Re(W) = [-3.3340016e-01 -1.6670008e+01 -3.3340016e+02]
# [[9.79431929e-01+0.j 4.89715965e+01+0.j 9.79431929e+02+0.j]
#  [1.95886386e-02+0.j 9.79431929e-01+0.j 1.95886386e+01+0.j]
#  [9.79431929e-04+0.j 4.89715965e-02+0.j 9.79431929e-01+0.j]]
# (2.9382957884427032+0j)
#  sensitivity matrix is:  [[3.33333333e-01+0.j 1.66666667e+01+0.j 3.33333333e+02+0.j]
#  [6.66666667e-03+0.j 3.33333333e-01+0.j 6.66666667e+00+0.j]
#  [3.33333333e-04+0.j 1.66666667e-02+0.j 3.33333333e-01+0.j]]
# [[0.0000e+00 0.0000e+00 0.0000e+00 4.6650e+00 6.1896e+01]
#  [6.7500e-01 7.0300e-01 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 4.7000e-02 6.5700e-01 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 1.9000e-02 6.8200e-01 0.0000e+00]
#  [0.0000e+00 0.0000e+00 0.0000e+00 6.1000e-02 8.0910e-01]]
#  magnitude of eigenvalues :
#  [2.88058155e-06 4.76116990e-01 7.45866397e-01 7.45866397e-01
#  9.51581737e-01]
# V ( eigenvectors as columns )= [[-7.20439943e-01+0.j         -3.09283738e-01+0.j
#   -1.20093429e-02-0.30807671j -1.20093429e-02+0.30807671j
#    3.41748635e-01+0.j        ]
#  [ 6.91748157e-01+0.j          9.20150536e-01+0.j
#   -9.31845451e-01+0.j         -9.31845451e-01-0.j
#    9.27985828e-01+0.j        ]
#  [-4.94860060e-02+0.j         -2.39088653e-01+0.j
#   -4.53781577e-02+0.18513335j -4.53781577e-02-0.18513335j
#    1.48058513e-01+0.j        ]
#  [ 1.37864822e-03+0.j          2.20643967e-02+0.j
#    1.49827612e-02+0.00585747j  1.49827612e-02-0.00585747j
#    1.04350976e-02+0.j        ]
#  [-1.03939984e-04+0.j         -4.04203265e-03+0.j
#   -1.56566529e-04-0.00402713j -1.56566529e-04+0.00402713j
#    4.46752665e-03+0.j        ]]
#  Last column of V: [0.34174864+0.j 0.92798583+0.j 0.14805851+0.j 0.0104351 +0.j
#  0.00446753+0.j]
# W= inv (V)= [[-1.40354941e+00+1.47152163e-16j -5.98968672e-06+1.86853331e-16j
#    8.95900534e-05+4.44089210e-16j -3.09791616e-03-9.17529321e-16j
#    1.07371652e+02-0.00000000e+00j]
#  [ 3.81617136e-01-5.40840566e-17j  2.69176892e-01-8.78046059e-17j
#   -1.29939709e+00-4.44089210e-16j  1.23704662e+01+1.08598266e-15j
#   -7.09362746e+01+1.63462577e-14j]
#  [-2.48162556e-01+6.97564129e-02j -2.84717065e-01-8.49582100e-03j
#   -1.23589732e-02-1.35344081e+00j  1.58610261e+01-4.04158781e+00j
#    4.14862913e+01+5.07232879e+01j]
#  [-2.48162556e-01-6.97564129e-02j -2.84717065e-01+8.49582100e-03j
#   -1.23589732e-02+1.35344081e+00j  1.58610261e+01+4.04158781e+00j
#    4.14862913e+01-5.07232879e+01j]
#  [ 1.69462938e-01+3.62584376e-17j  2.38900499e-01+2.79861637e-17j
#    1.26353832e+00-2.22044605e-16j  1.95902796e+01-3.06492331e-15j
#    7.36170000e+01-0.00000000e+00j]]
#  Last Row of Re(W) = [ 0.16946294  0.2389005   1.26353832 19.59027962 73.61699997]
# [[2.38535412e-01+0.j 3.36275469e-01+0.j 1.77855192e+00+0.j
#   2.75752060e+01+0.j 1.03623020e+02+0.j]
#  [6.47720163e-01+0.j 9.13123967e-01+0.j 4.82948812e+00+0.j
#   7.48778420e+01+0.j 2.81378429e+02+0.j]
#  [1.03342617e-01+0.j 1.45687329e-01+0.j 7.70536368e-01+0.j
#   1.19466285e+01+0.j 4.48934353e+01+0.j]
#  [7.28354135e-03+0.j 1.02679777e-02+0.j 5.43070579e-02+0.j
#   8.41993023e-01+0.j 3.16406920e+00+0.j]
#  [3.11826647e-03+0.j 4.39597840e-03+0.j 2.32502116e-02+0.j
#   3.60478301e-01+0.j 1.35461727e+00+0.j]]
# (4.118806039777399+0j)
#  sensitivity matrix is:  [[5.79137278e-02+0.j 8.16439196e-02+0.j 4.31812496e-01+0.j
#   6.69495133e+00+0.j 2.51585093e+01+0.j]
#  [1.57259205e-01+0.j 2.21696278e-01+0.j 1.17254565e+00+0.j
#   1.81795019e+01+0.j 6.83155327e+01+0.j]
#  [2.50904306e-02+0.j 3.53712527e-02+0.j 1.87077605e-01+0.j
#   2.90050767e+00+0.j 1.08996235e+01+0.j]
#  [1.76836231e-03+0.j 2.49295004e-03+0.j 1.31851457e-02+0.j
#   2.04426481e-01+0.j 7.68200583e-01+0.j]
#  [7.57080192e-04+0.j 1.06729435e-03+0.j 5.64489112e-03+0.j
#   8.75200963e-02+0.j 3.28885909e-01+0.j]]
