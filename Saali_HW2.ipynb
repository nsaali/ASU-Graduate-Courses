# %% [markdown]
# <a href="https://colab.research.google.com/github/nsaali/ASU-Graduate-Courses/blob/main/Saali_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nick Saali HW2 
import numpy as np 
import matplotlib.pyplot as plt 
import sympy 
from sympy import Function, Derivative, symbols
from sympy import simplify, checkodesol, Eq, solve, sin, cos
# Number 2
t = symbols('t')
N = symbols('N', cls = Function)

eq1 = Derivative(N(t), t) - 4*N(t)

eq2 = 3*sympy.exp(4*t)

checkodesol(eq1, eq2) # TRUE

# Number 3

eq3 = Eq(Derivative(N(t), t), 3*N(t)*(1-((N(t)/5))))

eq4 = 5/(1+sympy.exp(-3*t))

checkodesol(eq3, eq4) # TRUE

# Number 4

K, r, C = symbols('K, r, C')

eq5 = Eq(Derivative(N(t), t), r*N(t)*(1-((N(t)/K))))

eq6 = 5/(1+C*sympy.exp(-r*t))

checkodesol(eq5, eq6) # FALSE

# Number 6

import numpy as np
from matplotlib import pyplot as plt
from scipy import integrate

'''
fig = plt . figure ()
# Vector field
tgrid = np . linspace (-3 , 3 , 12 )
xgrid = np . linspace (-3 , 3 , 12 )
T , X = np . meshgrid ( tgrid , xgrid )
U = 1.0
V = 1 / (T ** 2 + X ** 2) # this is the right -hand - side of your ODE
# Normalize arrows
N = np . sqrt (U ** 2 + V ** 2)
U = U / N
V = V / N
# play with " scale " , etc . below to see what they do
plt.quiver(T , X , U , V , angles ="xy", scale_units = "xy",scale =7 , headlength =0 , headwidth =1 , color ="red")
plt . xlim ([-3 , 3])
plt . ylim ([-3 , 3])
plt . xlabel ("t")
plt . ylabel ("x")
plt . title (" Direction Field for dx/dt = 1/(t^2+x^2)")
plt . show ()
'''

# Number 7 with Number 9 included for each (direction field superimposed on ode solutions)
# a 

def vf (x , t):
  dx = np.zeros(1)
  dx[0] = x[0]+t**2
  return dx
t0 = -3.0
tEnd = 3.0
plt . figure ()
t = np . linspace (t0 , tEnd , 10000 )
# Run the following line to see the initial conditions
print (" ICs ", np . linspace (-3.0 , 3.0 , 9) )
# Following loop will plot a solution curve for each IC.
for x0 in np . linspace (-3.0 , 3.0 , 9):
  x_initial = [x0]
  x = integrate . odeint (vf , x_initial , t)
  plt . plot (t , x[:, 0], "-")
# Vector field
tgrid = np . linspace (-3 , 3 , 12 )
xgrid = np . linspace (-3 , 3 , 12 )
T , X = np . meshgrid ( tgrid , xgrid )
U = 1.0
V = X+T**2 
# Normalize arrows
Nnew = np.sqrt(U**2 + V**2)
U = U / Nnew
V = V / Nnew

plt.quiver(T , X , U , V , angles ="xy", scale_units = "xy",scale =3 , headlength =0.5 , headwidth =2 , color ="blue")
plt . xlim ([-3 , 3])
plt . ylim ([-3 , 3])
plt . xlabel ("t")
plt . ylabel ("x")
plt . title (" Direction Field for dx/dt = x + t^2")
plt . show ()

# b

def vf (x , t):
  dx = np.zeros(1)
  dx[0] = np.sin(t**2)
  return dx
t0 = -3.0
tEnd = 3.0
plt . figure ()
t = np . linspace (t0 , tEnd , 10000 )
# Run the following line to see the initial conditions
print (" ICs ", np . linspace (-3.0 , 3.0 , 9) )
# Following loop will plot a solution curve for each IC.
for x0 in np . linspace (-3.0 , 3.0 , 9):
  x_initial = [x0]
  x = integrate . odeint (vf , x_initial , t)
  plt . plot (t , x[:, 0], "-")

Z = np.sin(T**2)
# Normalize arrows
Nnew1 = np.sqrt(U**2 + Z**2)
U = U / Nnew1
Z = Z / Nnew1

plt.quiver(T , X , U , Z , angles ="xy", scale_units = "xy",scale =3 , headlength =0.5 , headwidth =2 , color ="purple")
plt . xlim ([-3 , 3])
plt . ylim ([-3 , 3])
plt . xlabel ("t")
plt . ylabel ("x")
plt . title (" Direction Field for dx/dt = sin(t^2)")
plt . show ()

# c

def vf (x , t):
  dx = np.zeros(1)
  dx[0] = x[0]*(1-x[0])
  return dx
t0 = -3.0
tEnd = 3.0
plt . figure ()
t = np . linspace (t0 , tEnd, 20)
# Run the following line to see the initial conditions
print (" ICs ", np . linspace (-3.0 , 3.0 , 9) )
# Following loop will plot a solution curve for each IC.
for x0 in np . linspace (-3.0 , 3.0 , 9):
  x_initial = [x0]
  x = integrate . odeint (vf , x_initial , t)
  plt . plot (t , x[:, 0], "-")


Q = X*(1-X)
# Normalize arrows
Nnew = np.sqrt(U**2 + Q**2)
U = U / Nnew
Q = Q / Nnew

plt.quiver(T , X , U , Q , angles ="xy", scale_units = "xy",scale =3 , headlength =0.5 , headwidth =2 , color ="green")
plt . xlim ([-3 , 3])
plt . ylim ([-3 , 3])
plt . xlabel ("t")
plt . ylabel ("x")
plt . title (" Direction Field for dx/dt = x(1-x)")
plt . show ()

# d

def vf (x , t):
  dx = np.zeros(1)
  dx[0] = x[0]*(1-x[0])*(x[0]-10)
  return dx
t0 = -3.0
tEnd = 3.0
plt . figure ()
t = np . linspace (t0 , tEnd, 2)
# Run the following line to see the initial conditions
print (" ICs ", np . linspace (-3.0 , 3.0 , 9) )
# Following loop will plot a solution curve for each IC.
for x0 in np . linspace (-3.0 , 3.0 , 9):
  x_initial = [x0]
  x = integrate . odeint (vf , x_initial , t)
  plt . plot (t , x[:, 0], "-")

Y = X*(1-X)*(X-10)
# Normalize arrows
Nnew2 = np.sqrt(U**2 + Y**2)
U = U / Nnew2
Y = Y / Nnew2

plt.quiver(T , X , U , Y , angles ="xy", scale_units = "xy",scale =3 , headlength =0.5 , headwidth =2 , color ="orange")
plt . xlim ([-3 , 3])
plt . ylim ([-3 , 3])
plt . xlabel ("t")
plt . ylabel ("x")
plt . title (" Direction Field for dx/dt = x(1-x)(x-10)")
plt . show ()

# Number 8

def vf (x , t): # note the different order
  dx = np.zeros(1)
  dx[0] = 1 / (t ** 2 + x[0] ** 2)
  return dx
t0 = -3.0
tEnd = 5.0
plt . figure ()
t = np . linspace (t0 , tEnd , 100 )

# Run the following line to see the initial conditions
print (" ICs ", np . linspace (-3.0 , 3.0 , 9) )
# Following loop will plot a solution curve for each IC.
for x0 in np . linspace (-3.0 , 3.0 , 9):
  x_initial = [x0]
  x = integrate . odeint (vf , x_initial , t)
  plt . plot (t , x[:, 0], "-")
# Reuse part of the code from the previous problem to superimpose the direction field .
R = 1 / (T ** 2 + X ** 2)
Nnew3 = np.sqrt (U ** 2 + R ** 2)
U = U / Nnew3
R = R / Nnew3
plt . quiver (T , X , U , R , angles ="xy", scale_units ="xy", scale =4 ,headlength =0.5 , headwidth =2)
plt . xlim ([-3 , 3])
plt . ylim ([-3 , 3])
plt . xlabel ("t")
plt . ylabel ("x")
plt . title (" Direction Field for dx/dt = 1/(t**2+x**2)")
plt . show ()
# Out:
#  ICs  [-3.   -2.25 -1.5  -0.75  0.    0.75  1.5   2.25  3.  ]
#  ICs  [-3.   -2.25 -1.5  -0.75  0.    0.75  1.5   2.25  3.  ]
#  ICs  [-3.   -2.25 -1.5  -0.75  0.    0.75  1.5   2.25  3.  ]
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# ...
